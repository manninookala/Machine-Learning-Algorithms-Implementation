# %%
import pandas as  pd
from sklearn.datasets import make_regression

# %%
data = make_regression(n_samples = 100, n_features = 1, n_targets = 1)
data
# Out:
# (array([[ 0.88362412],
#         [ 1.11461117],
#         [ 1.94953418],
#         [-1.54273036],
#         [ 0.90236813],
#         [-1.17775135],
#         [-1.81328242],
#         [-0.00456184],
#         [ 0.32316871],
#         [ 0.16640974],
#         [ 1.38161469],
#         [-1.88849243],
#         [ 1.0758715 ],
#         [-0.36897865],
#         [-0.98370746],
#         [-1.55693351],
#         [-1.01892849],
#         [ 1.5011568 ],
#         [-0.15549395],
#         [-0.2688658 ],
#         [-0.51535212],
#         [ 0.88136221],
#         [-0.03432426],
#         [-0.42067295],
#         [ 0.66771103],
#         [ 0.49362801],
#         [-0.17227267],
#         [ 2.47881615],
#         [-0.7024596 ],
#         [ 0.03997947],
#         [ 0.38759238],
#         [ 0.2360544 ],
#         [ 0.59368443],
#         [-0.28586268],
#         [-0.16387776],
#         [ 0.70740584],
#         [-1.51355268],
#         [-1.26489457],
#         [-1.33897955],
#         [-1.32222105],
# ...

# %%
y = data[1]
y
# Out:
# array([-15.63188619,  -3.3813217 , -11.05055399, -12.42806416,
#         -3.35648098, -35.02293839,  13.1289607 ,  14.65411253,
#        -17.16807108,   3.31403054])

# %%
# Converting into dataframe
df = pd.DataFrame(data[0], columns =['x'])

# %%
df
# Out:
#           x
# 0 -0.682558
# 1 -0.147644
# 2 -0.482516
# 3 -0.542665
# 4 -0.146559
# 5 -1.529258
# 6  0.573269
# 7  0.639864
# 8 -0.749635
# 9  0.144705

# %%
df['sq_x'] = df['x']**2
df.head()
# Out:
#           x      sq_x
# 0 -0.682558  0.465885
# 1 -0.147644  0.021799
# 2 -0.482516  0.232822
# 3 -0.542665  0.294485
# 4 -0.146559  0.021480

# %%
df['cb_x'] = df['x']**3
df.head()
# Out:
#           x      sq_x      cb_x
# 0 -0.682558  0.465885 -0.317994
# 1 -0.147644  0.021799 -0.003218
# 2 -0.482516  0.232822 -0.112341
# 3 -0.542665  0.294485 -0.159807
# 4 -0.146559  0.021480 -0.003148

# %%
import numpy as np
df['bias'] = np.ones(10)

# %%
df.drop('bias', axis = 'columns', inplace = True)
df
# Out:
#           x      sq_x      cb_x
# 0 -0.682558  0.465885 -0.317994
# 1 -0.147644  0.021799 -0.003218
# 2 -0.482516  0.232822 -0.112341
# 3 -0.542665  0.294485 -0.159807
# 4 -0.146559  0.021480 -0.003148
# 5 -1.529258  2.338629 -3.576367
# 6  0.573269  0.328637  0.188398
# 7  0.639864  0.409426  0.261977
# 8 -0.749635  0.561952 -0.421259
# 9  0.144705  0.020940  0.003030

# %%
df.insert(0,'bias', np.ones(10))
df
# Out:
#    bias         x      sq_x      cb_x
# 0   1.0 -0.682558  0.465885 -0.317994
# 1   1.0 -0.147644  0.021799 -0.003218
# 2   1.0 -0.482516  0.232822 -0.112341
# 3   1.0 -0.542665  0.294485 -0.159807
# 4   1.0 -0.146559  0.021480 -0.003148
# 5   1.0 -1.529258  2.338629 -3.576367
# 6   1.0  0.573269  0.328637  0.188398
# 7   1.0  0.639864  0.409426  0.261977
# 8   1.0 -0.749635  0.561952 -0.421259
# 9   1.0  0.144705  0.020940  0.003030

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(df,y)
# Out:
# LinearRegression()

# %%
ypreds = model.predict(df)

# %%
ypreds
# Out:
# array([-15.63188619,  -3.3813217 , -11.05055399, -12.42806416,
#         -3.35648098, -35.02293839,  13.1289607 ,  14.65411253,
#        -17.16807108,   3.31403054])

# %%
y
# Out:
# array([-15.63188619,  -3.3813217 , -11.05055399, -12.42806416,
#         -3.35648098, -35.02293839,  13.1289607 ,  14.65411253,
#        -17.16807108,   3.31403054])

# %%
model.coef_
# Out:
# array([ 0.00000000e+00,  2.29019200e+01, -6.49480469e-15,  2.66453526e-15])

# %%
x = data[0]
y =data[1]

# %%
model = LinearRegression()
model.fit(x,y)
ypreds = model.predict(x)

# %%
print(ypreds[:10])
print(y[:10])
# Out:
# [ 48.30473438  60.93201351 106.57442334 -84.33583821  49.329406
#  -64.38367314 -99.12600155  -0.24938044  17.66653759   9.09705636]
# [ 48.30473438  60.93201351 106.57442334 -84.33583821  49.329406
#  -64.38367314 -99.12600155  -0.24938044  17.66653759   9.09705636]

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color = 'red', label = 'True Values')
plt.plot(x,ypreds,color = 'green', label = 'Predicted Values')
plt.legend()
plt.show()

# %% [markdown]
# **Try drawing a graph using two features.**

# %%
# def cost(w, x,y)

# def gd(w, x, y):
#   w[0] = w[0]- 0.001*
