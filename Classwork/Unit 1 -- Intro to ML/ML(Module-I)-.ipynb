# %% [markdown]
# ## **09 Aug 2023**

# %% [markdown]
# Regerssion
#
# Linear regression (Continuous Variables)
#
# Variables : Continuous, Categorical
#
# Classfification (Categorical Variables)
#
#
# ____________
#
# ML methods are categorized into
# 1. **Dataset has features & target** : Supervised learning.(Used for predicting).
#
#   a. Linear Regression
#
#   b. Classification
#
# 2. **Unsupervised** : The dataset has only features.
#
#     a. Used for finding groups/patterns/clusters.
#
#     b. Dimensionality(feature) Reduction.

# %% [markdown]
# ### **Datasets:**
#
# 1. csv files - comma separated values (Easy to manipulate)
# 2. excel
# 3. json files
#
# Datasets are publicly available in
#
#   1. kaggle
#   2. UCI repository
#   3. data.gov.in

# %% [markdown]
# **Pandas** : Python package for loading and manipulating the data.

# %%
import pandas as pd

# %% [markdown]
# First upload the dataset into google-collab then use read_csv

# %%
#load dataset into dataframe
data = pd.read_csv('/content/sample_data/Housing.csv')

# %%
data.shape
# Out:
# (545, 13)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# # **10 Aug 2023**

# %%
data.head(2)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
faetures=['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']
target = 'price'

# %%
print(len(faetures))
# Out:
# 13

# %%
#check for null values /missing /not available value
data.isna()
#isna = is not available
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
data.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# Visualization : graphs
#
# Python contains two popular libtaries ,
#   1. Matplotlib.pyplot
#   2. seaborn

# %%
import matplotlib.pyplot as plt
# Is a plotting library used in Python.

# %% [markdown]
# Scatterplot is to see the relation between two variables.

# %%
plt.scatter(data['area'],data['price']) #Giving the x&y coordinates as Area &price
plt.xlabel('Area of house')
plt.ylabel('Price of the house')
plt.title('Area Vs Price')
plt.show()

# %%
plt.scatter(data['bedrooms'],data['price'])
plt.xlabel('No of Bedrooms')
plt.ylabel('Price of the house')
plt.title('Bedrroms Vs Price')
plt.show()

# %%
print(data['price'].min(),data['price'].max())
# Out:
# 1750000 13300000

# %%
print(data[['price','area']].min())
# Out:
# price    1750000
# area        1650
# dtype: int64

# %%
data.min()
# Out:
# price                 1750000
# area                     1650
# bedrooms                    1
# bathrooms                   1
# stories                     1
# mainroad                   no
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning            no
# parking                     0
# prefarea                   no
# furnishingstatus    furnished
# dtype: object

# %%
data.describe()
#Applicable for numeric columns- statistical information.
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# Object datatype - Strings, boolean,categorical, objects.

# %%
#datatype of diff. columns
data.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
data['mainroad'].head(5)
# Out:
# 0    yes
# 1    yes
# 2    yes
# 3    yes
# 4    yes
# Name: mainroad, dtype: object

# %%
data['prefarea'].head(5)
# Out:
# 0    yes
# 1     no
# 2    yes
# 3    yes
# 4     no
# Name: prefarea, dtype: object

# %%
#count how many yes & no are present.
data['mainroad'].value_counts()
# Out:
# yes    468
# no      77
# Name: mainroad, dtype: int64

# %%
#count how many yes & no are present.
data['prefarea'].value_counts()
# Out:
# no     417
# yes    128
# Name: prefarea, dtype: int64

# %%
data['airconditioning'].head()
# Out:
# 0    yes
# 1    yes
# 2     no
# 3    yes
# 4    yes
# Name: airconditioning, dtype: object

# %%
#count how many yes & no are present.
data['airconditioning'].value_counts()
# Out:
# no     373
# yes    172
# Name: airconditioning, dtype: int64

# %%
data['furnishingstatus'].head()
# Out:
# 0         furnished
# 1         furnished
# 2    semi-furnished
# 3         furnished
# 4         furnished
# Name: furnishingstatus, dtype: object

# %%
#count how many yes & no are present.
data['furnishingstatus'].value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %%
# Return uniques values of the data0frame
data['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
data[['furnishingstatus','airconditioning']].value_counts()
# Out:
# furnishingstatus  airconditioning
# semi-furnished    no                 162
# unfurnished       no                 133
# furnished         no                  78
# semi-furnished    yes                 65
# furnished         yes                 62
# unfurnished       yes                 45
# dtype: int64

# %% [markdown]
# Python has Machine Learning Module for different Algorithms like,
#   1. Linear Regression
#   2. Classification
#   3. Dimensionality Reduction
#   4. Clustering etc..
#
# ###  Is **ScKit-Learn(sklearn).**
#
# #### **ML Model Building** ::
#   1. Collect the dataset
#   2. Load the dataset
#   3. Data pre-processing  :: handling missing values, remove duplicates,   handle the outliners, rescale the features.
#   4. Build the model.
#   5. Evaluate the Model performance.
#   6. Repeat until satisfactory performance.

# %%
data[['area','bedrooms']].head()
# Out:
#    area  bedrooms
# 0  7420         4
# 1  8960         4
# 2  9960         3
# 3  7500         4
# 4  7420         4

# %% [markdown]
# # **16 Aug 2023**

# %% [markdown]
# Supervised : Features + Target
#
#   If target is continuous variable is called Regression.
#   IF target is cateforical is called Classification.
#
#
# Unsupervised : Faetures
#   Find some patterns/groups/Clusters.
#     1. Clustering : Datapoints are grouped/ clustered.
#     2. Dimensionality Reduction : Each feature is one dimension. If the dataset has too many features, reduce the no. of features.

# %% [markdown]
# Regression : The dataset has one or more Features + Target(What you want to  predict).
#   1. Target is continuous variable - float/int.
#   2. Features are also called as Independent variables
#   Target/Label is also called as Dependant variable ie, it depends onfature values.
#   4. Regression is to establish a function between target & features.
#   5. The funcyion is called refression function or model.
#
# tarfet = f( f1, f2, f3,....)
#
# target = b1*f1 + b2*f2 +...
#
# f1, f2....are feature values availble in the dataset.
#
# Target value is also available in dataset.
#
# Our job is to find value of faeture coefficients b1, b2,..

# %%
import pandas as pd
dataset = pd.read_csv('/content/sample_data/Housing.csv')

# %%
dataset.shape
# Out:
# (545, 13)

# %% [markdown]
# Datase has features & target.

# %%
dataset.columns     #Identifying the target and features. 1. target-price 2. faeture - area.
                    # price = b1*area  (find b1)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset['price'], dataset['area'])
plt.show()

# %% [markdown]
# SciKit Learn : python module that provides ML Algorithms.

# %%
from sklearn.linear_model import LinearRegression

# %%
 lr = LinearRegression()

# %%
x = dataset['area']
y = dataset['price']
print(type(x), type(y))
# Out:
# <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>

# %%
x.head()
# Out:
# 0    7420
# 1    8960
# 2    9960
# 3    7500
# 4    7420
# Name: area, dtype: int64

# %%
x.shape
# Out:
# (545,)

# %%
import numpy as np

# %%
x = x.values          #Convert series to numpy array.
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
x = np.reshape(x,(-1,1))

# %%
x.shape
# Out:
# (545, 1)

# %%
lr.fit(x,y)       #fit()is used for model building. Model Building : features array-x & target array-y is pased as parameters.
                          # This function returns the array of predicted target values.
# Out:
# LinearRegression()

# %%
lr.coef_      # This is the b1 Value.
# Out:
# array([461.97489427])

# %%
lr.intercept_
# Out:
# 2387308.48239643

# %% [markdown]
# **Regression Function ::**
#
#   Price = 2387308.48 + 461.97 * Area

# %%
print(ypred)
# Out:
# LinearRegression()

# %%
ypred = lr.predict(x)     # Predict for given x using LR function.

# %%
print(len(ypred), len(y))
# Out:
# 545 545

# %%
print(y[:5])
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
print(ypred[:5])
# Out:
# [5815162.19790048 6526603.53508057 6988578.42935335 5852120.18944231
#  5815162.19790048]

# %%
error1 = y[0]-ypred[0]          # Error is the difference between true value and predicted value.
error1
# Out:
# 7484837.802099517

# %% [markdown]
# Loss  = Sum of all errors across all the observations(545).

# %%
loss = abs(y-ypred).sum()
loss
# Out:
# 638906503.6666155

# %% [markdown]
# There is the lot of difference between the actual value and the predicted value.

# %% [markdown]
# ## **17 Aug 2023**
